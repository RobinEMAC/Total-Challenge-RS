# %%
import csv
import numpy as np
noun_file = 'TrainSample.csv'
#Toutes les données avec la description
data = list(csv.reader(open(noun_file , 'rt', encoding="utf-8"), delimiter = ';'))

#Retirer la description
data2 = []
for i in range(1,len(data)):
    data2.append([float(x.replace(',','.')) for x in data[i] if (('/' not in x)and(x!=''))])

#Prendre toutes les données sans les lignes vides    
data3 = []
for i in range(len(data2)):
    if len(data2[i])==44:
        data3.append(data2[i])

#Mettre en tableau 2D
data4 = np.zeros(np.shape(data3))
for i in range(np.shape(data3)[0]):
    for j in range(np.shape(data3)[1]):
        data4[i,j]=data3[i][j]

#Mettre en DataFrame
import pandas as pd
column_names = ['API','Surf_X','Surf_Y','Lateral_Length','Depth_TVD_PPLS','Erosion_PPLS','Pressure_PPLS','TOC_PPLS','Vcarb_PPLS','Vsand_PPLS','Vclay_PPLS','PR_PPLS','YM_PPLS','RHOB_PPLS','Res_PPLS','GR_PPLS','DT_PPLS','DTs_PPLS','Temperature','Temp_Anomaly','S3Tect_PPLS','S3_contrast_PPLS','Heat_Flow','Zone','Nbr_Stages','Frac_Gradient','Proppant_Designed','Proppant_in_Formation','Avg_Breakdown_Pressure','Avg_Treating_Pressure','Max_Treating_pressure','Min_Treating_Pressure','Avg_Rate_Slurry','Max_Rate_Slurry','Min_Rate_Slurry','ShutInPressure_Fil','ShutInPressure_Initial','ISIP','Shot_Density','Shot_Total','Proppant_per_ft','Stage_Spacing','GasCum360','OilCum360']
df = pd.DataFrame(data4, columns=column_names)
print(df)
# Out:
#        API    Surf_X    Surf_Y  Lateral_Length  Depth_TVD_PPLS  Erosion_PPLS  \
# 0    661.0  0.429600 -0.193201       -1.124200       -0.214336     -1.262296
# 1    523.0 -0.082672 -0.539854        1.286521        0.870034      0.717834
# 2    703.0 -0.457415 -0.082104       -0.781945        0.511093      0.592495
# 3    473.0  0.376282 -0.310432       -0.442801        0.025900     -1.093255
# 4    309.0 -0.113110 -0.111412        0.258511        0.190913      1.229474
# 5    772.0 -0.318181  0.375489        1.178244       -0.388169     -0.007005
# 6    774.0 -0.465668  0.782771        0.607611       -0.838949     -0.907872
# 7    269.0  0.406886 -0.238452       -0.488850       -0.120788     -1.202808
# 8    698.0  0.399069  0.379299       -0.518720       -1.105026     -1.931457
# 9    605.0  0.360877  0.093196       -0.439690       -0.623653     -1.424113
# 10   753.0  0.267113 -0.444272        0.788695        0.355025     -0.595267
# 11    66.0  1.648255 -1.275365       -0.587171        0.791208     -0.319257
# 12   228.0  0.277349 -0.439348        0.758826        0.335987     -0.641062
# 13    70.0  0.351014  0.033017       -1.124823       -0.516440     -1.312943
# 14   106.0  0.425759  0.081629       -1.269192       -0.661109     -1.503481
# 15   361.0  0.992658 -1.282477        0.126587        1.033214      0.508173
# 16   391.0  0.164692  0.627459       -0.461470       -1.258019     -1.370839
# 17   319.0  0.001073  0.298800       -0.553567       -0.597315      0.510352
# 18   790.0  0.080168 -0.360490       -0.972986        0.405899      0.310543
# 19   616.0  0.235212 -0.050393       -0.161530       -0.274371     -0.659906
# 20   780.0  0.300946  0.306655       -1.109888       -0.908954     -1.590451
# 21   694.0  1.060344 -1.091351        1.379863        0.697443      1.087195
# 22   748.0  0.636987 -0.410138       -0.489472       -0.016867     -1.023655
# 311      1.586689    0.155221        -0.547484      -0.176908   1.187857
# 312      0.664338   -0.544508         1.958077      -1.224405   0.031830
# 313      0.667339   -0.560750        -0.503946       0.919157  -0.957862
# 314      0.667339   -0.560750        -0.528055      -0.166873  -0.048286
#
#      OilCum360
# 0    -0.659768
# 1     1.782547
# 2     0.283035
# 3    -0.328650
# 4     0.975603
# 5    -0.123280
# 6     0.851118
# 7    -0.596578
# 8    -0.638283
# 9    -0.543498
# 10   -0.037341
# 11   -0.750131
# 12    0.127586
# 13   -0.825959
# 14   -0.840493
# 15   -0.343815
# 16   -0.778566
# 17    0.092831
# 18   -0.202901
# 19   -0.098636
# 20   -0.835438
# 21   -0.573829
# 22   -0.782990
# 23   -0.822168
# 24   -0.126440
# 25   -0.194686
# 26   -0.846812
# 27    0.104837
# 28   -0.840493
# 29   -0.586467
# ..         ...
# 285   2.028358
# 286  -0.217434
# 287  -0.256612
# 288  -0.620590
# 289   0.264078
# 290  -0.846812
# 291  -0.836070
# 292  -0.846180
# 293   0.111157
# 294   1.487447
# 295  -0.625645
# 296  -0.846812
# 297  -0.551712
# 298  -0.266723
# 299   1.103248
# 300  -0.061986
# 301   1.167703
# 302   0.453017
# 303   0.323477
# 304  -0.819640
# 305  -0.218066
# 306  -0.834174
# 307   3.315549
# 308  -0.680621
# 309  -0.805106
# 310   0.271029
# 311  -0.846180
# 312  -0.460086
# 313  -0.286944
# 314  -0.817113
#
# [315 rows x 44 columns]

# %%
#corr=[]
#for i in range(len(data3)):
#    l=[]
#    for j in range(len(data3[i])):
#        l.append(np.corrcoef(data3[i][j],data3[i][i])[0,1])
#    corr.append(l)

#Matrice de corrélation entre les caractéristiques
corr = np.zeros((np.shape(data4)[1],np.shape(data4)[1]))
for i in range(np.shape(data4)[1]):
    for j in range(np.shape(data4)[1]):
        corr[i,j]=np.corrcoef(data4[:,i],data4[:,j])[0,1]

# %%
import seaborn as sns
corr_df= pd.DataFrame(corr, columns=column_names, index=column_names)

# plot the heatmap
sns.heatmap(corr_df, 
        xticklabels=column_names,
        yticklabels=column_names)

#Embellir la heatmap
cmap = sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])]

corr_df.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36 th {
#           font-size: 7pt;
#     }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36 td {
#           padding: 0em 0em;
#     }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36 th:hover {
#           font-size: 12pt;
#     }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col1 {
#             background-color:  #db4f6b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col2 {
#             background-color:  #e68396;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col3 {
#             background-color:  #df617a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col4 {
#             background-color:  #dd5671;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col5 {
#             background-color:  #df617a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col6 {
#             background-color:  #e7899c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col7 {
#             background-color:  #e68396;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col8 {
#             background-color:  #e0667e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col9 {
#             background-color:  #e06880;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col10 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col11 {
#             background-color:  #e27389;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col12 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col13 {
#             background-color:  #df617a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col14 {
#             background-color:  #dd5a74;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col15 {
#             background-color:  #e26f86;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col16 {
#             background-color:  #dd5872;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col17 {
#             background-color:  #d94764;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col18 {
#             background-color:  #e27288;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col19 {
#             background-color:  #e16d85;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col20 {
#             background-color:  #de5f79;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col21 {
#             background-color:  #e68699;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col22 {
#             background-color:  #e3748a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col23 {
#             background-color:  #e26f86;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col24 {
#             background-color:  #e57f93;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col25 {
#             background-color:  #e47c91;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col26 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col27 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col28 {
#             background-color:  #de5c76;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col29 {
#             background-color:  #e26f86;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col30 {
#             background-color:  #df637c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col31 {
#             background-color:  #e27087;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col32 {
#             background-color:  #dd5a74;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col33 {
#             background-color:  #dd5872;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col34 {
#             background-color:  #e26f86;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col35 {
#             background-color:  #e16b82;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col36 {
#             background-color:  #e58195;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col37 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col38 {
#             background-color:  #e3768c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col39 {
#             background-color:  #d94563;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col40 {
#             background-color:  #e7899c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col41 {
#             background-color:  #dc516d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col42 {
#             background-color:  #df627b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row0_col43 {
#             background-color:  #e58094;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row1_col0 {
#             background-color:  #f3c4cd;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11e7_b379_aced5c471e36row1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7cbf15ba_d0fd_11

# %%
#Tri sur les différentes corrélation
for i in range(np.shape(corr)[0]):
    for j in range(np.shape(corr)[0]):
        if np.abs(corr[i,j])<0.5:
            corr[i,j]=0
        else:
            corr[i,j]=np.abs(corr[i,j])

corr_df= pd.DataFrame(corr, columns=column_names, index=column_names)

corr_df.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_2f53912c_d100_11e7_b379_aced5c471e36 th {
#           font-size: 7pt;
#     }    #T_2f53912c_d100_11e7_b379_aced5c471e36 td {
#           padding: 0em 0em;
#     }    #T_2f53912c_d100_11e7_b379_aced5c471e36 th:hover {
#           font-size: 12pt;
#     }    #T_2f53912c_d100_11e7_b379_aced5c471e36 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col1 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col2 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col3 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col4 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col5 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col6 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col7 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col8 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col9 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col10 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col11 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col12 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col13 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col14 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col15 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col16 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col17 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col18 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col19 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col20 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col21 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col22 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col23 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col24 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col25 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col26 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col27 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col28 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col29 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col30 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col31 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col32 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col33 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col34 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col35 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col36 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col37 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col38 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col39 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col40 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col41 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col42 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row0_col43 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row1_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11e7_b379_aced5c471e36row1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_2f53912c_d100_11
